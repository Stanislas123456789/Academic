# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# !pip install xlrd
# Out:
# ...
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\Stanislas Michel\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\Stanislas Michel\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\Stanislas Michel\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\Stanislas Michel\AppData\Local\Programs\Python\Python312\Lib\site-packages)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df=pd.read_excel(r"D:\backup d\FGV\EBAPE\NOVO\propostas grad\TS\IPCA.XLS",sheet_name="IPCA",usecols="A:B",
parse_dates=["DATA"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df=pd.read_excel(r"D:\backup d\FGV\EBAPE\NOVO\propostas grad\TS\IPCA.XLS",sheet_name="IPCA",usecols="A:B",
#       2 parse_dates=["DATA"])
#
# NameError: name 'pd' is not defined

# %%
df
# Out:
#                     IPCA
# DATA
# 1979-12-01  7.618300e-09
# 1980-01-01  8.122300e-09
# 1980-02-01  8.497300e-09
# 1980-03-01  9.010400e-09
# 1980-04-01  9.486700e-09
# ...                  ...
# 2024-08-01  6.966500e+03
# 2024-09-01  6.997150e+03
# 2024-10-01  7.036330e+03
# 2024-11-01  7.063770e+03
# 2024-12-01  7.100500e+03
#
# [541 rows x 1 columns]

# %%
# Converter a coluna 'DATA' para datetime 
df["DATA"] = pd.to_datetime(df["DATA"], dayfirst=True) 
# Definir a coluna 'DATA' como índice (opcional, mas facilita) 
df.set_index("DATA", inplace=True) 
# Criar o gráfico plt.figure(figsize=(12, 6)) 
plt.plot(df.index, df["IPCA"], marker="o", linestyle="-", color="b", label="IPCA") 
# Configurar rótulos e título 
plt.xlabel("Data") 
plt.ylabel("Valor do IPCA") 
plt.title("Evolução do Valor do IPCA  índice (dez. 1993 = 100)") 
plt.xticks(rotation=45) 
# Rotacionar datas para melhor visualização 
plt.legend() 
plt.grid() 

# Mostrar o gráfico 
plt.show()
